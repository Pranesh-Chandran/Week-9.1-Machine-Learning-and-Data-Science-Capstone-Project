# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("synthetic_ev_battery_health.csv")

# %%
dataset
# Out:
#      Battery_ID  Cycles  Voltage_V  Current_A  Temperature_C  \
# 0        B00001     165       3.43       3.45           29.2
# 1        B00002     386       4.19       3.09           30.0
# 2        B00003     303       4.18       3.96           28.8
# 3        B00004    1572       4.02       1.46           22.8
# 4        B00005    1708       3.30       0.89           27.7
# ...         ...     ...        ...        ...            ...
# 9995     B09996    1076       3.82       1.18           25.5
# 9996     B09997     398       3.80       3.36           26.0
# 9997     B09998     452       3.64       4.98           28.7
# 9998     B09999     116       4.12       3.12           27.9
# 9999     B10000     379       3.75       1.22           46.0
#
#       Internal_Resistance_mOhm  Capacity_Ah    SOH
# 0                         40.2        47.54  95.33
# 1                         48.6        46.98  90.41
# 2                         39.6        46.37  91.79
# 3                         92.2        33.49  69.18
# 4                        100.9        33.65  66.52
# ...                        ...          ...    ...
# 9995                      75.0        39.35  77.71
# 9996                      43.0        46.16  92.31
# 9997                      47.2        46.04  89.68
# 9998                      30.5        48.63  96.10
# 9999                      47.2        46.09  89.20
#
# [10000 rows x 8 columns]

# %%
dataset.isnull().sum()
# Out:
# Battery_ID                  0
# Cycles                      0
# Voltage_V                   0
# Current_A                   0
# Temperature_C               0
# Internal_Resistance_mOhm    0
# Capacity_Ah                 0
# SOH                         0
# dtype: int64

# %%
dataset.describe()
# Out:
#              Cycles     Voltage_V     Current_A  Temperature_C  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     999.763400      3.701544      2.741918      34.921090
# std      574.884249      0.289164      1.303848       8.631356
# min        0.000000      3.200000      0.500000      20.000000
# 25%      504.000000      3.450000      1.620000      27.500000
# 50%      999.000000      3.700000      2.750000      34.800000
# 75%     1497.000000      3.950000      3.870000      42.300000
# max     2000.000000      4.200000      5.000000      50.000000
#
#        Internal_Resistance_mOhm   Capacity_Ah           SOH
# count              10000.000000  10000.000000  10000.000000
# mean                  70.022450     40.004203     78.502644
# std                   23.133155      5.771934     11.618488
# min                   25.200000     29.040000     55.100000
# 25%                   50.300000     35.050000     68.560000
# 50%                   69.950000     40.020000     78.540000
# 75%                   89.900000     44.942500     88.420000
# max                  114.600000     50.940000    100.000000

# %% [markdown]
# ### Removing unwanted columns

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Battery_ID                10000 non-null  object
#  1   Cycles                    10000 non-null  int64
#  2   Voltage_V                 10000 non-null  float64
#  3   Current_A                 10000 non-null  float64
#  4   Temperature_C             10000 non-null  float64
#  5   Internal_Resistance_mOhm  10000 non-null  float64
#  6   Capacity_Ah               10000 non-null  float64
#  7   SOH                       10000 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 625.1+ KB

# %%
dataset.columns
# Out:
# Index(['Battery_ID', 'Cycles', 'Voltage_V', 'Current_A', 'Temperature_C',
#        'Internal_Resistance_mOhm', 'Capacity_Ah', 'SOH'],
#       dtype='object')

# %%
dataset.sample()
# Out:
#      Battery_ID  Cycles  Voltage_V  Current_A  Temperature_C  \
# 6556     B06557    1298       3.55       3.21           24.2
#
#       Internal_Resistance_mOhm  Capacity_Ah    SOH
# 6556                      80.1        37.57  73.91

# %%
dataset
# Out:
#      Battery_ID  Cycles  Voltage_V  Current_A  Temperature_C  \
# 0        B00001     165       3.43       3.45           29.2
# 1        B00002     386       4.19       3.09           30.0
# 2        B00003     303       4.18       3.96           28.8
# 3        B00004    1572       4.02       1.46           22.8
# 4        B00005    1708       3.30       0.89           27.7
# ...         ...     ...        ...        ...            ...
# 9995     B09996    1076       3.82       1.18           25.5
# 9996     B09997     398       3.80       3.36           26.0
# 9997     B09998     452       3.64       4.98           28.7
# 9998     B09999     116       4.12       3.12           27.9
# 9999     B10000     379       3.75       1.22           46.0
#
#       Internal_Resistance_mOhm  Capacity_Ah    SOH
# 0                         40.2        47.54  95.33
# 1                         48.6        46.98  90.41
# 2                         39.6        46.37  91.79
# 3                         92.2        33.49  69.18
# 4                        100.9        33.65  66.52
# ...                        ...          ...    ...
# 9995                      75.0        39.35  77.71
# 9996                      43.0        46.16  92.31
# 9997                      47.2        46.04  89.68
# 9998                      30.5        48.63  96.10
# 9999                      47.2        46.09  89.20
#
# [10000 rows x 8 columns]

# %%
useless_col = ['Battery_ID']

# %%
dataset = dataset.drop(columns = useless_col, axis=1)

# %%
dataset.to_csv("pre_processed_synthetic_ev.csv", index=False)

# %%
dataset.isnull().sum()
# Out:
# Cycles                      0
# Voltage_V                   0
# Current_A                   0
# Temperature_C               0
# Internal_Resistance_mOhm    0
# Capacity_Ah                 0
# SOH                         0
# dtype: int64

# %%
dataset.describe()
# Out:
#              Cycles     Voltage_V     Current_A  Temperature_C  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     999.763400      3.701544      2.741918      34.921090
# std      574.884249      0.289164      1.303848       8.631356
# min        0.000000      3.200000      0.500000      20.000000
# 25%      504.000000      3.450000      1.620000      27.500000
# 50%      999.000000      3.700000      2.750000      34.800000
# 75%     1497.000000      3.950000      3.870000      42.300000
# max     2000.000000      4.200000      5.000000      50.000000
#
#        Internal_Resistance_mOhm   Capacity_Ah           SOH
# count              10000.000000  10000.000000  10000.000000
# mean                  70.022450     40.004203     78.502644
# std                   23.133155      5.771934     11.618488
# min                   25.200000     29.040000     55.100000
# 25%                   50.300000     35.050000     68.560000
# 50%                   69.950000     40.020000     78.540000
# 75%                   89.900000     44.942500     88.420000
# max                  114.600000     50.940000    100.000000
